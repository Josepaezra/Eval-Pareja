# %%
Jupyter Clinvar design

# %%
    # Valoraciones
     
    print("Para poder establecer el nivel en el que esta el prospecto y poder compararlo con otros, primero es necesario establecer el sistemas de preferencias propio, por lo que debera calificar con un numero del 0 al 5 que tanto valora las caracteristicas, donde 0 significa que no tiene importancia y 5 maxima importancia")
     
    val_fig_paterna =float(input("Ingrese el valor de su figura paterna: "))
    val_fig_materna=float(input("Ingrese el valor de su figura materna: "))
    val_trato_hacia_pad=float(input("Ingrese el valor del trato hacia su padre: "))
    val_trato_hacia_mad=float(input("Ingrese el valor del trato hacia su madre: "))
    val_dinamica_familiar=float(input("Ingrese el valor de su dinamica familiar: "))
    val_dinamica_familiares_secundarios=float(input("Ingrese el valor de su dinamica familiar secundaria: "))
     
    val_salario=float(input("Ingrese el valor de su salario: "))
     
    val_circulo_social=float(input("Ingrese el valor de su circulo social: "))
     
    val_impacto=float(input("Ingrese el valor del impacto de su trabajo: "))
     
    val_hobbie=float(input("Ingrese el valor de sus hobbies :"))
    val_ocio=float(input("Ingrese el valor de sus actividades de ocio: "))
     
    val_autoconocimiento_cuidado_fisico=float(input("Ingrese el valor de autoconocimento del cuidado fisico :"))
    val_autoconocimiento_cuidado_mental=float(input("Ingrese el valor de autoconocimiento del cuidado mental: "))
    val_autoconocimiento_cuidado_emocional=float(input("Ingrese el valor del cuidado emociona:l "))
    val_desarrollo_personal=float(input("Ingrese el valor de su desarrollo personal: "))
     
    val_oral=float(input("Ingrese el valor de sus orales: "))
    val_masturbacion =float(input("Ingrese el valor de su forma de masturbar: "))
    val_penetracion=float(input("Ingrese el valor de su forma de penetrar: "))
    val_autoestima_sex=float(input("Ingrese el valor de su autoestima en el sexo: "))
    val_confianza_sex=float(input("Ingrese el valor de su confianza en el sexo: "))
    val_seguridad_sex=float(input("Ingrese el valor de su seguridad en el sexo: "))
    val_experiencia_sex=float(input("Ingrese el valor de su experiencia sexual: "))
     
    val_cara=float(input("Ingrese el valor de su cara: "))
    val_cuerpo=float(input("Ingrese el valor de su cuerpo: "))
    val_org_sexuales  =float(input("Ingrese el valor de sus genitales: "))
     
    val_ojos=float(input("Ingrese el valor de sus ojos :"))
    val_nariz=float(input("Ingrese el valor de su nariz:  "))
    val_boca=float(input("Ingrese el valor de du boca: "))
    val_cabello=float(input("Ingrese el valor de su cabell :"))
    val_dientes=float(input("Ingrese el valor de sus dientes: "))
    val_piel=float(input("Ingrese el valor de su piel: "))
     
    val_musculatura =float(input("Ingrese el valor de musculatura: "))
    val_altura=float(input("Ingrese el valor de altura: "))
     
    val_color=float(input("Ingrese el valor del color de sus genitales: "))
    val_forma=float(input("Ingrese el valor de la forma de sus genitales: ") )
    val_medida=float(input("Ingrese el valor de la medida de sus genitales: "))
     
    val_talentos=float(input("Ingrese el valor de sus talentos: "))
    val_inteligencia_emocional=float(input("Ingrese el valor de su inteligencia emocional: "))
     
    val_orientacion_al_logro=float(input("Ingrese el valor de orientacion al logro: "))
    val_estabilidad_emocional=float(input("Ingrese el valor de estabilidad emocional: "))
    val_consciente_orden=float(input("Ingrese el valor de su consciencia del orden: "))
    val_apertura=float(input("Ingrese el valor de apertura a experiencias: "))
    val_inteligencia=float(input("Ingrese el valor de su inteligencia: ")) 
    val_actitud=float(input("Ingrese el valor de su actitud : "))
    val_social_influyente=float(input("Ingrese el valor de influencia social: "))
     
    val_reciprocidad_romantica=float(input("Ingrese el valor de su reciprocidad romantica: "))


    print("A continuacion introduca el valor de un atributo personal, ejemplo amor a mascotas") 
    val_misc_1=float(input("Ingrese el valor de miscelanea 1: "))
     
    val_sentimental=float(input("Ingrese el valor de los sentimientos:"))

# %%
    # Puntajes
    Nombre=input("Introduzca el nombre de la persona quien desea calcular su puntaje:")
    print("Comience otorgando los puntos de la persona:")
          
    fig_paterna =float(input("Ingrese el puntaje de su figura paterna: "))
    fig_materna=float(input("Ingrese el puntaje de su figura materna:  "))
    trato_hacia_pad=float(input("Ingrese e puntaje de su trato hacia su padre: "))
    trato_hacia_mad=float(input("Ingrese el puntaje de su trato hacia su madre: "))
    dinamica_familiar=float(input("Ingrese el puntaje de su dinamica familiar: "))
    dinamica_familiares_secundarios=float(input("Ingrese el puntaje de su dinamica familiar secundario:  "))
     
    salario=float(input("Ingrese el puntaje de su salario:"))
     
    circulo_social=float(input("Ingrese el puntaje de  su circulo social: "))
     
    impacto=float(input("Ingrese el puntaje del impacto de su trabajo: "))
     
    hobbie=float(input("Ingrese el puntaje de su hobbie: "))
    ocio=float(input("Ingrese el puntaje de su ocio: "))
     
    autoconocimiento_cuidado_fisico=float(input("Ingrese el puntaje de su conocimiento del cuidado fisico"))
    autoconocimiento_cuidado_mental=float(input("Ingrese el puntaje de su autoconocimiento del cuidado mental"))
    autoconocimiento_cuidado_emocional=float(input("Ingrese el puntaje de su autoconocimiento del cuidado emocional "))
    desarrollo_personal=float(input("Ingrese el puntaje de desarrollo_personal"))
     
    oral=float(input("Ingrese el puntaje de oral"))
    masturbacion =float(input("Ingrese el puntaje de mastubacion"))
    penetracion=float(input("Ingrese el puntaje de penetracion"))
    autoestima_sex=float(input("Ingrese el puntaje de autoestima_sex"))
    confianza_sex=float(input("Ingrese el puntaje de confianza_sex"))
    seguridad_sex=float(input("Ingrese el puntaje de seguridad_sex"))
    experiencia_sex=float(input("Ingrese el puntaje de experiencia_sex"))
     
    cara=float(input("Ingrese el puntaje de cara"))
    cuerpo=float(input("Ingrese el puntaje de cuerpo"))
    org_sexuales  =float(input("Ingrese el puntaje de org_sexuales"))
     
    ojos=float(input("Ingrese el puntaje de ojos"))
    nariz=float(input("Ingrese el puntaje de nariz"))
    boca=float(input("Ingrese el puntaje de boca"))
    cabello=float(input("Ingrese el puntaje de cabello"))
    dientes=float(input("Ingrese el puntaje de dientes"))
    piel=float(input("Ingrese el puntaje de piel"))
     
    musculatura =float(input("Ingrese el puntaje de musculatura"))
    altura=float(input("Ingrese el puntaje de altura"))
     
    color=float(input("Ingrese el puntaje de color"))
    forma=float(input("Ingrese el puntaje de forma") )
    medida=float(input("Ingrese el puntaje de medida"))
     
    talentos=float(input("Ingrese el puntajede talentos"))
    inteligencia_emocional=float(input("Ingrese el puntaje de inteligencia_emocional"))
     
    orientacion_al_logro=float(input("Ingrese el puntaje de orientacion_al_logro"))
    estabilidad_emocional=float(input("Ingrese el puntaje de estabilidad_emocional"))
    consciente_orden=float(input("Ingrese el puntaje de consciente_orden"))
    apertura=float(input("Ingrese el puntaje de apertura"))
    inteligencia=float(input("Ingrese el puntaje de inteligencia")     )
    actitud=float(input("Ingrese el puntaje de actitud"))
    social_influyente=float(input("Ingrese el puntaje de social_influyente"))
     
    reciprocidad_romantica=float(input("Ingrese el puntaje de reciprocidad_romantica"))
   
    misc_1 =float(input("Ingrese el puntaje  de misc_1"))
     
    sentimental=float(input("Ingrese el puntaje de los sentimientos"))

  # Calculo con los valores: 
    
    familia= fig_paterna *val_fig_paterna + fig_materna*val_fig_materna  + trato_hacia_pad*val_trato_hacia_pad + trato_hacia_mad*val_trato_hacia_mad  + dinamica_familiar*val_dinamica_familiar + dinamica_familiares_secundarios*val_dinamica_familiares_secundarios 
    
    finanzas= salario * val_salario
    
    amigos= circulo_social * val_circulo_social
    
    trabajo=   impacto * val_impacto
    
    personal=hobbie*val_hobbie + ocio *val_ocio
    
    salud_habitos_estilo_de_vida= autoconocimiento_cuidado_fisico *val_autoconocimiento_cuidado_fisico+ autoconocimiento_cuidado_mental * val_autoconocimiento_cuidado_mental + autoconocimiento_cuidado_emocional * val_autoconocimiento_cuidado_emocional + desarrollo_personal * val_desarrollo_personal
    
    
    sexo = oral*val_oral + masturbacion * val_masturbacion + penetracion * val_penetracion + autoestima_sex * val_autoestima_sex + confianza_sex * val_confianza_sex + seguridad_sex * val_seguridad_sex + experiencia_sex * val_experiencia_sex
    
    fisico= cara*val_cara + cuerpo*val_cuerpo + org_sexuales* val_org_sexuales
    
    rostro=ojos*val_ojos + nariz* val_nariz + boca * val_boca+ cabello*val_cabello + dientes* val_dientes + piel* val_piel
    
    cuerpo_= musculatura* val_musculatura + altura * val_altura
    organos_sexuales= color* val_color + forma * val_forma + medida * val_medida
    
    habilidades= talentos * val_talentos + inteligencia_emocional*val_inteligencia_emocional
    
    personalidad_valores= orientacion_al_logro* val_orientacion_al_logro+ estabilidad_emocional* val_estabilidad_emocional +consciente_orden *val_consciente_orden + apertura * val_apertura + inteligencia * val_inteligencia + actitud * val_actitud + social_influyente * val_social_influyente
    
    compatibilidad= reciprocidad_romantica * val_reciprocidad_romantica
   
    
    miscelaneas= misc_1 * val_misc_1
     
     
    sentimental_= sentimental*val_sentimental

    total= familia + finanzas + amigos + trabajo + personal + salud_habitos_estilo_de_vida +sexo + fisico + rostro + cuerpo + organos_sexuales + habilidades + personalidad_valores + compatibilidad + miscelaneas + sentimental_
 
    
    valoraciones= {
    #Valoraciones

    "valor de su figura paterna":val_fig_paterna, 
    "valor de su figura materna":val_fig_materna,
    "valor del trato hacia su padre":val_trato_hacia_pad,
    "valor del trato hacia su madre":val_trato_hacia_mad,
    "valor de su dinamica familiar":val_dinamica_familiar,
    "valor de su dinamica familiar secundaria":val_dinamica_familiares_secundarios,
     
    "valor de su salario":val_salario,
     
    "valor de su circulo social":val_circulo_social,
     
    "valor del impacto de su trabajo":val_impacto,
     
    "valor de sus hobbies":val_hobbie, 
    "valor de sus actividades de ocio":val_ocio,
     
    "valor de autoconocimento del cuidado fisico":val_autoconocimiento_cuidado_fisico,
    "valor de autoconocimiento del cuidado mental ":val_autoconocimiento_cuidado_mental,
    "valor del cuidado emocional ":val_autoconocimiento_cuidado_emocional,
    "valor de su desarrollo personal ":val_desarrollo_personal,
     
    "valor de sus orales":val_oral,
    "valor de su forma de masturbar":val_masturbacion ,
    "valor de su forma de penetrar":val_penetracion,
    "valor de su autoestima en el sexo":val_autoestima_sex,
    "valor de su confianza en el sexo":val_confianza_sex,
    "valor de su seguridad en el sexo":val_seguridad_sex,
    "valor de su experiencia sexual":val_experiencia_sex,
     
    "valor de su cara":val_cara,
    "valor de su cuerpo":val_cuerpo,
    "valor de sus genitales":val_org_sexuales , 
     
    "valor de sus ojos":val_ojos,
    "valor de su nariz":val_nariz,
    "valor de su boca":val_boca,
    "valor de su cabello":val_cabello,
    "valor de sus dientes":val_dientes,
    "valor de su piel":val_piel,
     
    "valor de musculatura":val_musculatura, 
    "valor de altura":val_altura,
     
    "valor del color de sus genitales":val_color,
    "valor de la forma de sus genitales" :val_forma,
    "valor de la medida de sus genitales":val_medida,
     
    "valor de sus talentos":val_talentos,
    "valor de su inteligencia emocional":val_inteligencia_emocional,
     
    "valor de orientacion al logro":val_orientacion_al_logro,
    "valor de estabilidad emocional":val_estabilidad_emocional,
    "valor de su consciencia del orden":val_consciente_orden,
    "valor de apertura a experiencias":val_apertura,
    "valor de su inteligencia":val_inteligencia,
    "valor de su actitud":val_actitud,
    "valor de influencia social":val_social_influyente,
    "valor de su reciprocidad romantica":val_reciprocidad_romantica,
     
    "valor de miscelanea":val_misc_1,
     
    "valor de los sentimientos":val_sentimental,
    }

    Datos= {
          
    #Calificaciones      
          
    "figura paterna":fig_paterna ,
    "figura materna":fig_materna,
    "trato hacia su padre":trato_hacia_pad,
    "trato hacia su madre":trato_hacia_mad,
    "dinamica familiar":dinamica_familiar,
    "dinamica familiar secundario":dinamica_familiares_secundarios,
     
    "salario":salario,
     
    "circulo social":circulo_social,
     
    "impacto":impacto,
     
    "hobbie":hobbie,
    "ocio":ocio,
     
    "autoconocimiento del cuidado fisico":autoconocimiento_cuidado_fisico,
    "autoconocimiento_cuidado_mental":autoconocimiento_cuidado_mental,
    "autoconocimiento_cuidado_emocional":autoconocimiento_cuidado_emocional,
    "desarrollo_personal":desarrollo_personal ,
     
    "oral":oral,
    "mastubacion":masturbacion ,
    "penetracion":penetracion,
    "autoestima_sex":autoestima_sex,
    "confianza_sex":confianza_sex,
    "seguridad_sex":seguridad_sex,
    "experiencia_sexual":experiencia_sex,
     
    "cara":cara,
    "cuerpo":cuerpo,
    "org_sexuales":org_sexuales,  
     
    "ojos":ojos,
    "nariz":nariz,
    "boca":boca,
    "cabello":cabello,
    "dientes":dientes,
    "piel":piel,
     
    "musculatura":musculatura,
    "altura":altura,
     
    "color":color,
    "forma":forma,
    "medida":medida,
     
    "talentos":talentos,
    "inteligencia_emocional":inteligencia_emocional,
     
    "orientacion_al_logro":orientacion_al_logro,
    "estabilidad_emocional":estabilidad_emocional,
    "consciente_orden":consciente_orden,
    "apertura":apertura,
    "inteligencia":inteligencia,
    "actitud":actitud,
    "social_influyente":social_influyente,
     
    "reciprocidad_romantica":reciprocidad_romantica,
     
    "misc_1":misc_1,
     
    "sentimientos":sentimental,

    #Valores sumados

    "familia":familia,
    "finanzas":finanzas,
    "amigos":amigos,
    "trabajo":trabajo,
    "personal":personal,
    "salud_habitos_estilo_de_vida":salud_habitos_estilo_de_vida,
    
    "sexo":sexo ,
    "fisico":fisico,
    "rostro":rostro,
    "cuerpo_":cuerpo_,
    "organos_sexuales":organos_sexuales,
    
    "habilidades":habilidades,
    
    "personalidad_valores":personalidad_valores,
    "compatibilidad":compatibilidad,
    
    "miscelaneas":miscelaneas,
     
    "sentimental_":sentimental_,

    "total": total
    
    }

# %%
asignacion_puntajes()

# %%
    #Correrse una sola vez para guardar las valoraciones
    Evaluaciones={}
    Evaluaciones=valoraciones
    agenda_fichero = open("Evaluaciones_Parejas.json", "w")
    # Esta sentencia escribe el diccionario en el fichero
    agenda_fichero.write(str(Evaluaciones))

    # Esta sentencia cierra el fichero que has abierto con la funcion open()
    agenda_fichero.close()

# %%
    Evaluaciones={}

    Evaluaciones[Nombre]=Datos


    agenda_fichero = open("Evaluaciones_Parejas.json", "r+",encoding="utf8")
    # Esta sentencia escribe el diccionario en el fichero
    agenda_fichero.write(str(Evaluaciones))

    # Esta sentencia cierra el fichero que has abierto con la funcion open()
    agenda_fichero.close()
